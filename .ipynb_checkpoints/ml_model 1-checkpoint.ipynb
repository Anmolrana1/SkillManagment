# %%
import pandas as pd

# %% [markdown]
# # Data Gathering

# %%
project=pd.read_csv('Project.projectexperiences.csv')
certificate=pd.read_csv('Project.certificates.csv') 
users=pd.read_csv('Project.userdetails.csv')
skills=pd.read_csv('Project.skilldetails.csv')
skills
# Out:
#                            _id    Empid              skillName   Proficiency  \
# 0     660bc7802e1f83fa6a7b27ac    Emp_8  Requirements Analysis       Advance
# 1     660bc7802e1f83fa6a7b2790    Emp_1                Support        Expert
# 2     660bc7802e1f83fa6a7b279d    Emp_4          Data Analysis  Intermidiate
# 3     660bc7802e1f83fa6a7b278e    Emp_0                 Vue.js       Advance
# 4     660bc7802e1f83fa6a7b2794    Emp_2          Communication      Beginner
# ...                        ...      ...                    ...           ...
# 1994  660bc7802e1f83fa6a7b2f43  Emp_491          User Research  Intermidiate
# 1995  660bc7802e1f83fa6a7b2f53  Emp_495          Microservices       Advance
# 1996  660c30597ecede045f8aaee6    Emp_0                Angular        Expert
# 1997  660ed9afd077065a8bba296e    Emp_0                 Kotlin      Advanced
# 1998  660eda6fd3cca031481a3507    Emp_0                   Ruby  Intermediate
#
#       __v
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ...   ...
# 1994  NaN
# 1995  NaN
# 1996  0.0
# 1997  0.0
# 1998  0.0
#
# [1999 rows x 5 columns]

# %%
certificate
# Out:
#       Unnamed: 0    Empid          certificateName  \
# 0              0  Emp_180    Requirements Analysis
# 1              1   Emp_71                      CSS
# 2              2  Emp_302              Wireframing
# 3              3  Emp_207         Network Security
# 4              4  Emp_329                     HTML
# ...          ...      ...                      ...
# 1992        1992  Emp_393                    CI/CD
# 1993        1993  Emp_294  Test-Driven Development
# 1994        1994  Emp_377             Data Science
# 1995        1995  Emp_135              Prototyping
# 1996        1996  Emp_321             Data Science
#
#              issuingOrganization   issueDate  ExpireDate  \
# 0                      Combs Ltd  1980-11-15  2024-05-05
# 1                  Johnson Group  1977-10-18  2024-05-02
# 2     Torres, Johnston and Baker  2008-09-07  2024-05-04
# 3                    Smith Group  1981-07-13  2024-04-08
# 4         Davis, Kirby and Davis  1976-01-21  2024-04-16
# ...                          ...         ...         ...
# 1992             Lloyd-Wilkinson  1984-11-19  2024-04-10
# 1993                   King-Kane  1972-10-05  2024-04-10
# 1994   Cantrell, Curtis and Kane  1996-01-30  2024-04-24
# 1995      Diaz, Hess and Ellison  1998-07-01  2024-05-02
# 1996                Barron-Perez  1986-10-03  2024-04-09
#
#                               credentialID    Status
# 0     a055435e-863c-41ac-bd62-0046c358394e  Approved
# 1     5a5d0257-c736-4e2f-822f-9701e6fc064c  Approved
# 2     f51ea522-5106-4558-a6ee-61c98120dbda  Approved
# 3     01ea5e37-102d-4758-af56-c98eca6bd9e0  Approved
# 4     d0b9c077-aae9-4f82-8751-48b6d7a75179  Approved
# ...                                    ...       ...
# 1992  78cc238c-32f5-4181-ad57-5b1bcc18d2a3  Approved
# 1993  b8ebca29-2536-4612-ab6e-233569fa25d1  Approved
# 1994  3f8fd93d-4057-42d4-b791-dfe909858ebb  Approved
# 1995  9e58b6c2-fb01-4ec2-8e7d-4a25762e9beb  Approved
# 1996  4e5a6403-4f3a-49cb-92a8-87f4e04a7199  Approved
#
# [1997 rows x 8 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert data to DataFrame
df_data = pd.DataFrame(certificate)

# Count the frequency of each certificate
certificate_counts = df_data['certificateName'].value_counts()

# Plotting
plt.figure(figsize=(10, 6))
certificate_counts.plot(kind='bar', color='skyblue')
plt.title('Frequency of Certificates')
plt.xlabel('Certificate')
plt.ylabel('Frequency')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
certificate_status=pd.read_csv('certificate_smms.csv')
certificate_status
# Out:
#              certificateName  Num_of_emp  Approved
# 0                       .NET          23        15
# 1              Accessibility          33        20
# 2        Agile Methodologies          35        15
# 3   Agile Product Management          32        19
# 4                    Angular          29        13
# ..                       ...         ...       ...
# 67              UI/UX Design          28        16
# 68             User Research          36        18
# 69              User Stories          29        15
# 70                    Vue.js          31        13
# 71               Wireframing          33        12
#
# [72 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# Data
certificate_names = certificate_status['certificateName']
num_of_emp = certificate_status['Num_of_emp']
approved = certificate_status['Approved']

# Plot
plt.figure(figsize=(20, 6))
plt.bar(certificate_names, approved, color='skyblue')
plt.xlabel('Certificate Name')
plt.ylabel('Number of Approvals')
plt.title('Number of Approvals for Different Certificate Names')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
skills=pd.DataFrame(skills)
skills
# Out:
#                            _id    Empid              skillName   Proficiency  \
# 0     660bc7802e1f83fa6a7b27ac    Emp_8  Requirements Analysis       Advance
# 1     660bc7802e1f83fa6a7b2790    Emp_1                Support        Expert
# 2     660bc7802e1f83fa6a7b279d    Emp_4          Data Analysis  Intermidiate
# 3     660bc7802e1f83fa6a7b278e    Emp_0                 Vue.js       Advance
# 4     660bc7802e1f83fa6a7b2794    Emp_2          Communication      Beginner
# ...                        ...      ...                    ...           ...
# 1994  660bc7802e1f83fa6a7b2f43  Emp_491          User Research  Intermidiate
# 1995  660bc7802e1f83fa6a7b2f53  Emp_495          Microservices       Advance
# 1996  660c30597ecede045f8aaee6    Emp_0                Angular        Expert
# 1997  660ed9afd077065a8bba296e    Emp_0                 Kotlin      Advanced
# 1998  660eda6fd3cca031481a3507    Emp_0                   Ruby  Intermediate
#
#       __v
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ...   ...
# 1994  NaN
# 1995  NaN
# 1996  0.0
# 1997  0.0
# 1998  0.0
#
# [1999 rows x 5 columns]

# %%
skill_count = skills.groupby('skillName').size().reset_index(name='EmployeeCount')

top_10_skills = skill_count.sort_values(by='EmployeeCount', ascending=False).head(10)

plt.figure(figsize=(10, 6))
plt.bar(top_10_skills['skillName'], top_10_skills['EmployeeCount'], color='skyblue')
plt.xlabel('Skill Name')
plt.ylabel('Number of Employees')
plt.title('Top 10 Skills by Number of Employees')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # skill data cleaning

# %%
##skill datda
import pandas as pd

# Assuming skills is your DataFrame containing skills data
skills = pd.DataFrame(skills)

def get_skills_for_employee(emp_id, skills_df):
    try:
        employee_skills = skills_df[skills_df['Empid'] == emp_id]
        return employee_skills
    except Exception as e:
        print('Error fetching skills:', e)
        return None

skills_data = []  # Initialize skills_data as an empty list
for employee_id in skills['Empid'].unique():  # Iterate over unique employee IDs in the DataFrame
    employee_skills = get_skills_for_employee(employee_id, skills)
    if employee_skills is not None and not employee_skills.empty:
        skill_list = [{'skillName': row['skillName'], 'proficiency': row['Proficiency']} for index, row in employee_skills.iterrows()]
        skills_data.append({'Empid': employee_id, 'skills': skill_list})
    else:
        print('No skills found for employee ID:', employee_id)

#print('Skills data:', skills_data)

# %%
skills_data=pd.DataFrame(skills_data)

# %%
skills_data
# Out:
#        Empid                                             skills
# 0      Emp_8  [{'skillName': 'Requirements Analysis', 'profi...
# 1      Emp_1  [{'skillName': 'Support', 'proficiency': 'Expe...
# 2      Emp_4  [{'skillName': 'Data Analysis', 'proficiency':...
# 3      Emp_0  [{'skillName': 'Vue.js', 'proficiency': 'Advan...
# 4      Emp_2  [{'skillName': 'Communication', 'proficiency':...
# ..       ...                                                ...
# 494  Emp_422  [{'skillName': 'Flask', 'proficiency': 'Expert...
# 495  Emp_491  [{'skillName': 'Agile Methodologies', 'profici...
# 496  Emp_497  [{'skillName': 'User Stories', 'proficiency': ...
# 497  Emp_401  [{'skillName': 'Flask', 'proficiency': 'Interm...
# 498  Emp_417  [{'skillName': 'User Research', 'proficiency':...
#
# [499 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert data to DataFrame
df_data = pd.DataFrame(project)

# Count the frequency of each certificate
certificate_counts = df_data['projectType'].value_counts()

# Plotting
plt.figure(figsize=(10, 6))
certificate_counts.plot(kind='bar', color='skyblue')
plt.title('Frequency of projectType')
plt.xlabel('projectType')
plt.ylabel('Frequency')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # project Data cleaning

# %%
#project data 
import ast  # Import the ast module to parse the string representation of the list

project = pd.DataFrame(project)

def get_project_for_employee(emp_id, project_df):
    try:
        employee_project = project_df[project_df['Empid'] == emp_id]
        return employee_project
    except Exception as e:
        print('Error fetching project:', e)
        return None

projects_data = []  # Initialize projects_data as an empty list
for employee_id in project['Empid'].unique():  # Iterate over unique employee IDs in the DataFrame
    employee_project = get_project_for_employee(employee_id, project)
    if employee_project is not None and not employee_project.empty:
        project_list = [{'projectType': row['projectType'], 'Tech_stack': ast.literal_eval(row['Tech_stack'])} for index, row in employee_project.iterrows()]
        projects_data.append({'Empid': employee_id, 'projects': project_list})
    else:
        print('No projects found for employee ID:', employee_id)

#print('Projects data:', projects_data)

# %%
project_data=pd.DataFrame(projects_data)

# %%
project_data
# Out:
#        Empid                                           projects
# 0      Emp_0  [{'projectType': 'Data Analyzer', 'Tech_stack'...
# 1      Emp_1  [{'projectType': 'Virtual Assistant', 'Tech_st...
# 2      Emp_2  [{'projectType': 'Healthcare Management System...
# 3      Emp_3  [{'projectType': 'Inventory Management System'...
# 4      Emp_4  [{'projectType': 'Human Resource Management Sy...
# ..       ...                                                ...
# 495  Emp_495  [{'projectType': 'Healthcare Management System...
# 496  Emp_496  [{'projectType': 'Help Desk Software', 'Tech_s...
# 497  Emp_497  [{'projectType': 'Help Desk Software', 'Tech_s...
# 498  Emp_498  [{'projectType': 'Sales Forecasting Software',...
# 499  Emp_499  [{'projectType': 'Online Marketplace', 'Tech_s...
#
# [500 rows x 2 columns]

# %% [markdown]
# # certificate data cleaning

# %%
import pandas as pd

certificate = pd.DataFrame(certificate)

def get_certificates_for_employee(emp_id, certificate_df):
    try:
        employee_certificate = certificate_df[certificate_df['Empid'] == emp_id]
        return employee_certificate
    except Exception as e:
        print('Error fetching certificate:', e)
        return None

certificate_data = []  # Initialize skills_data as an empty list
for employee_id in certificate['Empid'].unique():  # Iterate over unique employee IDs in the DataFrame
    employee_certificate = get_skills_for_employee(employee_id, certificate)
    if employee_certificate is not None and not employee_certificate.empty:
        certificate_list = [{'certificateName': row['certificateName'], 'Status': row['Status']} for index, row in employee_certificate.iterrows()]
        certificate_data.append({'Empid': employee_id, 'certificate': certificate_list})
    else:
        print('No certificate found for employee ID:', employee_id)

# %%
certificate_data=pd.DataFrame(certificate_data)

# %%
certificate_data
# Out:
#        Empid                                        certificate
# 0    Emp_180  [{'certificateName': 'Requirements Analysis', ...
# 1     Emp_71  [{'certificateName': 'CSS', 'Status': 'Approve...
# 2    Emp_302  [{'certificateName': 'Wireframing', 'Status': ...
# 3    Emp_207  [{'certificateName': 'Network Security', 'Stat...
# 4    Emp_329  [{'certificateName': 'HTML', 'Status': 'Approv...
# ..       ...                                                ...
# 494  Emp_394  [{'certificateName': 'Accessibility', 'Status'...
# 495  Emp_105  [{'certificateName': 'MySQL', 'Status': 'Appro...
# 496  Emp_209  [{'certificateName': 'Cybersecurity', 'Status'...
# 497  Emp_335  [{'certificateName': 'Flask', 'Status': 'Appro...
# 498   Emp_39  [{'certificateName': 'Objective-C', 'Status': ...
#
# [499 rows x 2 columns]

# %%
import pandas as pd

# Convert 'users' DataFrame to a list of dictionaries
users_data = []
for index, row in users.iterrows():
    # Check for NaN values and convert them to empty strings
    first_name = row['FirstName'] if pd.notna(row['FirstName']) else ''
    last_name = row['LastName'] if pd.notna(row['LastName']) else ''
    
    data = {
        'Empid': row['Empid'],
        'Name': first_name + ' ' + last_name
    }
    users_data.append(data)

# Display the result
#print(users_data)

# %%
users_data=pd.DataFrame(users_data)

# %%
users_data
# Out:
#                  Empid               Name
# 0               Emp_17        Vivie Eisak
# 1               Emp_28        Kata Creasy
# 2               Emp_23    Britteny Lannen
# 3                Emp_4  Gwendolen Whorall
# 4               Emp_27      Robert Danzey
# ..                 ...                ...
# 500            Emp_501     suraj pokriyal
# 501            Emp_504     suraj pokriyal
# 502        Emp_5044353     suraj pokriyal
# 503  Emp_5044353sdfsdf     suraj pokriyal
# 504           emp_5978        ashish rana
#
# [505 rows x 2 columns]

# %% [markdown]
# #  Data Integration

# %%
merged_data = pd.merge(users_data, skills_data ,on='Empid', how='inner')

# %%
merged_data= pd.merge(merged_data, project_data ,on='Empid', how='inner')

# %%
merged_data= pd.merge(certificate_data, merged_data ,on='Empid', how='inner')

# %%
merged_data
# Out:
#        Empid                                        certificate  \
# 0    Emp_180  [{'certificateName': 'Requirements Analysis', ...
# 1     Emp_71  [{'certificateName': 'CSS', 'Status': 'Approve...
# 2    Emp_302  [{'certificateName': 'Wireframing', 'Status': ...
# 3    Emp_207  [{'certificateName': 'Network Security', 'Stat...
# 4    Emp_329  [{'certificateName': 'HTML', 'Status': 'Approv...
# ..       ...                                                ...
# 494  Emp_394  [{'certificateName': 'Accessibility', 'Status'...
# 495  Emp_105  [{'certificateName': 'MySQL', 'Status': 'Appro...
# 496  Emp_209  [{'certificateName': 'Cybersecurity', 'Status'...
# 497  Emp_335  [{'certificateName': 'Flask', 'Status': 'Appro...
# 498   Emp_39  [{'certificateName': 'Objective-C', 'Status': ...
#
#                   Name                                             skills  \
# 0       Cassy Berkeley  [{'skillName': 'Troubleshooting', 'proficiency...
# 1          Isa Munkley  [{'skillName': 'CSS', 'proficiency': 'Advance'...
# 2      Olivero Cuttler  [{'skillName': 'Problem Solving', 'proficiency...
# 3      Rodolphe McNern  [{'skillName': 'Ruby', 'proficiency': 'Expert'...
# 4           Lem Sobtka  [{'skillName': 'Containerization', 'proficienc...
# ..                 ...                                                ...
# 494      Audi Hodcroft  [{'skillName': 'Data Analysis', 'proficiency':...
# 495   Marline Zannotti  [{'skillName': 'Artificial Intelligence', 'pro...
# 496  Granville Bontein  [{'skillName': 'Leadership', 'proficiency': 'E...
# 497       Kellen Villa  [{'skillName': 'Objective-C', 'proficiency': '...
# 498      Jacklin Oddey  [{'skillName': 'Support', 'proficiency': 'Expe...
#
#                                               projects
# 0    [{'projectType': 'Inventory Management System'...
# 1    [{'projectType': 'Sales Forecasting Software',...
# 2    [{'projectType': 'Web Application', 'Tech_stac...
# 3    [{'projectType': 'Educational Software', 'Tech...
# 4    [{'projectType': 'Asset Management System', 'T...
# ..                                                 ...
# 494  [{'projectType': 'Booking System', 'Tech_stack...
# 495  [{'projectType': 'Ticketing System', 'Tech_sta...
# 496  [{'projectType': 'Inventory Control System', '...
# 497  [{'projectType': 'Online Marketplace', 'Tech_s...
# 498  [{'projectType': 'Crypto Trader', 'Tech_stack'...
#
# [499 rows x 5 columns]

# %%
merged_data.iloc[1]
# Out:
# Empid                                                     Emp_71
# certificate    [{'certificateName': 'CSS', 'Status': 'Approve...
# Name                                                 Isa Munkley
# skills         [{'skillName': 'CSS', 'proficiency': 'Advance'...
# projects       [{'projectType': 'Sales Forecasting Software',...
# Name: 1, dtype: object

# %%
data = {
    "certificate_name": ["Certificate_A", "Certificate_B", "Certificate_C", "Certificate_D"],
    "skill_name": ["Skill_1", "Skill_2", "Skill_3", "Skill_4"],
    "tech_stack": ["Tech_A", "Tech_B", "Tech_C", "Tech_D"],
    "skill_proficiency": ["Expert", "Intermediate", "Advanced", "Intermediate"],
    "certificate_status": ["Approved", "Not Approved", "Approved", "Not Approved"]
}

# %%
#pip install scikit-learn

# %% [markdown]
# # Data Transformation

# %%
merged_data['certificate_name'] = merged_data['certificate'].apply(lambda x: [cert['certificateName'] for cert in x])
merged_data['certificate_status'] = merged_data['certificate'].apply(lambda x: [cert['Status'] for cert in x])
merged_data['skill_name'] = merged_data['skills'].apply(lambda x: [skill['skillName'] for skill in x])
merged_data['skill_proficiency'] = merged_data['skills'].apply(lambda x: [skill['proficiency'] for skill in x])
merged_data['project_type'] = merged_data['projects'].apply(lambda x: [proj['projectType'] for proj in x])
merged_data['tech_stack'] = merged_data['projects'].apply(lambda x: [','.join(proj['Tech_stack']) for proj in x])

# Drop the original nested columns
merged_data.drop(['certificate', 'skills', 'projects'], axis=1, inplace=True)

# %%
merged_data.iloc[1]
# Out:
# Empid                                                            Emp_71
# Name                                                        Isa Munkley
# certificate_name                   [CSS, Problem Solving, Vue.js, .NET]
# certificate_status             [Approved, Approved, Approved, Approved]
# skill_name                         [CSS, Problem Solving, Vue.js, .NET]
# skill_proficiency              [Advance, Expert, Advance, Intermidiate]
# project_type          [Sales Forecasting Software, Event Management ...
# tech_stack            [Continuous Integration,Technical Writing,Vue....
# Name: 1, dtype: object

# %%
# Flatten the 'certificate_name' column
merged_data['certificate_name'] = merged_data['certificate_name'].apply(lambda x: ','.join(x))

# Flatten the 'certificate_status' column
merged_data['certificate_status'] = merged_data['certificate_status'].apply(lambda x: ','.join(x))

# Flatten the 'skill_name' column
merged_data['skill_name'] = merged_data['skill_name'].apply(lambda x: ','.join(x))

# Flatten the 'skill_proficiency' column
merged_data['skill_proficiency'] = merged_data['skill_proficiency'].apply(lambda x: ','.join(x))

# Flatten the 'project_type' column
merged_data['project_type'] = merged_data['project_type'].apply(lambda x: ','.join(x))

# Flatten the 'tech_stack' column
merged_data['tech_stack'] = merged_data['tech_stack'].apply(lambda x: ','.join(x))

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Convert data to DataFrame
df_Data = pd.DataFrame(data)

# Plotting the distribution of skill proficiency levels by certificate status
sns.countplot(x='skill_proficiency', hue='certificate_status', data=df_Data)
plt.title('Distribution of Skill Proficiency by Certificate Status')
plt.xlabel('Skill Proficiency')
plt.ylabel('Count')
plt.legend(title='Certificate Status')
plt.show()

# %% [markdown]
# # Final Data

# %%
merged_data
# Out:
#        Empid               Name  \
# 0    Emp_180     Cassy Berkeley
# 1     Emp_71        Isa Munkley
# 2    Emp_302    Olivero Cuttler
# 3    Emp_207    Rodolphe McNern
# 4    Emp_329         Lem Sobtka
# ..       ...                ...
# 494  Emp_394      Audi Hodcroft
# 495  Emp_105   Marline Zannotti
# 496  Emp_209  Granville Bontein
# 497  Emp_335       Kellen Villa
# 498   Emp_39      Jacklin Oddey
#
#                                       certificate_name  \
# 0    Requirements Analysis,MongoDB,Technical Writin...
# 1                      CSS,Problem Solving,Vue.js,.NET
# 2    Wireframing,Network Security,Problem Solving,A...
# 3                  Network Security,MongoDB,NoSQL,Ruby
# 4               HTML,JavaScript,Containerization,Azure
# ..                                                 ...
# 494  Accessibility,DevOps,Data Analysis,Responsive ...
# 495  MySQL,Machine Learning,Collaboration,Artificia...
# 496  Cybersecurity,Accessibility,Leadership,User St...
# 497        Flask,User Research,RESTful API,Objective-C
# 498                  Objective-C,GraphQL,Support,Azure
#
#                       certificate_status  \
# 0    Approved,Approved,Approved,Approved
# 1    Approved,Approved,Approved,Approved
# 2    Approved,Approved,Approved,Approved
# 3    Approved,Approved,Approved,Approved
# 4    Approved,Approved,Approved,Approved
# ..                                   ...
# 494  Approved,Approved,Approved,Approved
# 495  Approved,Approved,Approved,Approved
# 496  Approved,Approved,Approved,Approved
# 497  Approved,Approved,Approved,Approved
# 498  Approved,Approved,Approved,Approved
#
#                                             skill_name  \
# 0    Troubleshooting,MongoDB,Technical Writing,Requ...
# 1                      CSS,Problem Solving,Vue.js,.NET
# 2    Problem Solving,Wireframing,Network Security,A...
# 3                  Ruby,Network Security,NoSQL,MongoDB
# 4               Containerization,JavaScript,HTML,Azure
# ..                                                 ...
# 494  Data Analysis,DevOps,Accessibility,Responsive ...
# 495  Artificial Intelligence,MySQL,Collaboration,Ma...
# 496  Leadership,Cybersecurity,User Stories,Accessib...
# 497        Objective-C,RESTful API,Flask,User Research
# 498                  Support,GraphQL,Objective-C,Azure
#
#                                  skill_proficiency  \
# 0               Expert,Advance,Intermidiate,Expert
# 1              Advance,Expert,Advance,Intermidiate
# 2                   Expert,Beginner,Expert,Advance
# 3          Expert,Expert,Intermidiate,Intermidiate
# 4    Intermidiate,Intermidiate,Expert,Intermidiate
# ..                                             ...
# 494                  Expert,Expert,Expert,Beginner
# 495                 Expert,Beginner,Advance,Expert
# 496                    Expert,Expert,Expert,Expert
# 497            Expert,Intermidiate,Advance,Advance
# 498          Expert,Beginner,Intermidiate,Beginner
#
#                                           project_type  \
# 0    Inventory Management System,Budget Planner,Inv...
# 1    Sales Forecasting Software,Event Management So...
# 2    Web Application,Customer Service Software,Docu...
# 3    Educational Software,Event Management Software...
# 4    Asset Management System,Social Networking Plat...
# ..                                                 ...
# 494  Booking System,Desktop Software,Human Resource...
# 495  Ticketing System,Retail Management System,POS ...
# 496  Inventory Control System,Document Management S...
# 497  Online Marketplace,Document Management System,...
# 498  Crypto Trader,Data Analyzer,Appointment Schedu...
#
#                                             tech_stack
# 0    Google Cloud Platform,NoSQL,AWS,User Research,...
# 1    Continuous Integration,Technical Writing,Vue.j...
# 2    HTML,React,Vue.js,Wireframing,Penetration Test...
# 3    Ruby,HTML,Vue.js,JavaScript,GraphQL,Flask,CI/C...
# 4    Kotlin,Java,AWS,Data Visualization,Communicati...
# ..                                                 ...
# 494  Agile Methodologies,Business Analysis,MongoDB,...
# 495  Troubleshooting,Agile Product Management,HTML,...
# 496  User Research,MongoDB,Prototyping,Documentatio...
# 497  MongoDB,Penetration Testing,Problem Solving,Gi...
# 498  PHP,UI/UX Design,Cybersecurity,Test-Driven Dev...
#
# [499 rows x 8 columns]

# %%
merged_data.to_csv("Transformed_data.csv")

# %%
merged_data.iloc[1]
# Out:
# Empid                                                            Emp_71
# Name                                                        Isa Munkley
# certificate_name                        CSS,Problem Solving,Vue.js,.NET
# certificate_status                  Approved,Approved,Approved,Approved
# skill_name                              CSS,Problem Solving,Vue.js,.NET
# skill_proficiency                   Advance,Expert,Advance,Intermidiate
# project_type          Sales Forecasting Software,Event Management So...
# tech_stack            Continuous Integration,Technical Writing,Vue.j...
# Name: 1, dtype: object

# %% [markdown]
# # Recommendation

# %%
# DataFrame from sample data
df = merged_data
df.loc[1]
# Out:
# Empid                                                            Emp_71
# Name                                                        Isa Munkley
# certificate_name                        CSS,Problem Solving,Vue.js,.NET
# certificate_status                  Approved,Approved,Approved,Approved
# skill_name                              CSS,Problem Solving,Vue.js,.NET
# skill_proficiency                   Advance,Expert,Advance,Intermidiate
# project_type          Sales Forecasting Software,Event Management So...
# tech_stack            Continuous Integration,Technical Writing,Vue.j...
# Name: 1, dtype: object

# %%
# Function to allocate projects to employees based on requirements
def allocate_projects(df, required_tech_stack, required_skill_proficiency, required_project_types):
    allocated_projects = {}
    for index, row in df.iterrows():
        certificate_status = row['certificate_status'].split(',')
        skill_names = row['skill_name'].split(',')
        skill_proficiency = row['skill_proficiency'].split(',')
        tech_stack = row['tech_stack'].split(',')
        project_types = row['project_type'].split(',')

        # Check if employee meets the required skill proficiency and tech stack criteria
        meets_criteria = False
        if (set(required_tech_stack).issubset(tech_stack) or 
            any(skill in required_tech_stack for skill in tech_stack)) and \
           (required_skill_proficiency in skill_proficiency or 'Expert' in skill_proficiency) and \
           'Approved' in certificate_status:
            meets_criteria = True

        # Check if employee is allocated to any of the required project types
        allocated_to_project = any(project.lower() in required_project_types for project in project_types)

        # Allocate project if employee meets criteria and allocated to project type(s)
        if meets_criteria and allocated_to_project:
            allocated_projects[row['Empid']] = project_types

    return allocated_projects

# Sample data
data = {
    'Empid': ['Emp_1'],
    'Name': ['Odilia Hedon'],
    'certificate_name': ['React,Support,C#,Vue.js'],
    'certificate_status': ['Approved,Rejected,Approved,Approved'],
    'skill_name': ['Support,C#,React,Vue.js'],
    'skill_proficiency': ['Expert,Expert,Intermidiate,Intermidiate'],
    'project_type': ['Virtual Assistant,Supply Chain Management Software'],
    'tech_stack': ['React,Data Science,NoSQL,Python,Product Management']
}

df = pd.DataFrame(merged_data)

# Required parameters
required_tech_stack = ['React', 'Node.js', 'c#']
required_skill_proficiency = 'Intermidiate'
required_project_types = ['virtual assistant', 'supply chain management software']

# Call the allocate_projects function with the provided parameters
allocated_projects = allocate_projects(df, required_tech_stack, required_skill_proficiency, required_project_types)

# Display the allocated projects
if allocated_projects:
    print("Yes for Employees:")
    for emp_id, project_types in allocated_projects.items():
        print(f"Employee {emp_id} is allocated to project type(s): {', '.join(project_types)}")
else:
    print("No employees meet the criteria for project allocation.")
# Out:
# Yes for Employees:
# Employee Emp_228 is allocated to project type(s): Educational Software, Virtual Assistant, POS System, Remote Support Tool
# Employee Emp_309 is allocated to project type(s): Human Resource Management System, Online Marketplace, Content Delivery Network, Supply Chain Management Software
# Employee Emp_414 is allocated to project type(s): Virtual Assistant, Inventory Management System, Budget Planner, Dashboard Creator
# Employee Emp_465 is allocated to project type(s): Educational Software, Web Application, Virtual Assistant, Data Analyzer
# Employee Emp_125 is allocated to project type(s): Virtual Assistant, Warehouse Management System, Content Management System, Data Analyzer
# Employee Emp_183 is allocated to project type(s): Data Analyzer, Content Delivery Network, Virtual Assistant, Virtual Assistant
# Employee Emp_387 is allocated to project type(s): Payment Gateway, Supply Chain Management Software, Appointment Scheduling Software, Workflow Management Software
# Employee Emp_61 is allocated to project type(s): Virtual Assistant, Task Management Tool, Event Management Software, Crypto Trader
# Employee Emp_50 is allocated to project type(s): Accounting Software, Ticketing System, Supply Chain Management Software, Data Analyzer
# Employee Emp_358 is allocated to project type(s): Virtual Assistant, Project Management Software, Project Management Software, Budget Planner
# Employee Emp_144 is allocated to project type(s): Virtual Assistant, Web Application, Backup Solution, Healthcare Management System
# Employee Emp_156 is allocated to project type(s): Healthcare Management System, Event Management Software, Virtual Assistant, Supply Chain Management Software
# Employee Emp_73 is allocated to project type(s): Event Management Software, Document Management System, Virtual Assistant, Chatbot
# Employee Emp_307 is allocated to project type(s): Content Management System, Survey Software, Social Networking Platform, Supply Chain Management Software
# Employee Emp_51 is allocated to project type(s): Supply Chain Management Software, Accounting Software, Online Marketplace, Customer Service Software
# Employee Emp_389 is allocated to project type(s): Supply Chain Management Software, Online Marketplace, Survey Software, Warehouse Management System
# Employee Emp_224 is allocated to project type(s): Supply Chain Management Software, Online Marketplace, Fleet Management System, Healthcare Management System
# Employee Emp_388 is allocated to project type(s): Virtual Assistant, Payment Gateway, Online Marketplace, Email Client
# Employee Emp_48 is allocated to project type(s): Supply Chain Management Software, Desktop Software, CRM System, Customer Relationship Management
# Employee Emp_210 is allocated to project type(s): Budget Planner, Email Client, Supply Chain Management Software, Payment Gateway
# Employee Emp_63 is allocated to project type(s): Mobile App, POS System, Accounting Software, Virtual Assistant
# Employee Emp_161 is allocated to project type(s): Project Management Software, Event Management Software, Crypto Trader, Supply Chain Management Software
# Employee Emp_301 is allocated to project type(s): Dashboard Creator, Supply Chain Management Software, Warehouse Management System, Retail Management System
# Employee Emp_155 is allocated to project type(s): POS System, Supply Chain Management Software, Mobile App, Social Networking Platform
# Employee Emp_457 is allocated to project type(s): Supply Chain Management Software, Booking System, Event Management Software, Social Networking Platform
# Employee Emp_143 is allocated to project type(s): Supply Chain Management Software, Booking System, Inventory Management System, Data Analyzer

# %%
df=pd.DataFrame(merged_data)    
allocated_employees = []
def allocate_employee_to_project(df, required_tech_stack, required_skill_proficiency):
    allocated_employees = []

    # Iterate over each row of the DataFrame
    for index, row in df.iterrows():
        # Split tech_stack, skill_proficiency, and certificate_status strings into lists
        tech_stack = row['tech_stack'].split(',')
        skill_proficiency = row['skill_proficiency'].split(',')
        certificate_status = row['certificate_status'].split(',')

        # Count the number of matching skills
        matching_skills = sum(1 for skill, proficiency, status in zip(tech_stack, skill_proficiency, certificate_status)
                              if skill.strip().lower() in required_tech_stack and 
                              ('Advance' in proficiency.lower() or 'expert' in proficiency.lower()) and 
                              'approved' in status.lower())

        # Calculate the percentage of matching skills
        matching_percentage = (matching_skills / len(required_tech_stack)) * 100

        # Check if the employee meets the criteria
        if matching_percentage >= 40:
            allocated_employees.append({'Employee_id':row['Empid'],'Name':row['Name']})

    return allocated_employees

# Test the function with example data
allocated_employees = allocate_employee_to_project(df, ['java', 'ci/cd'], 'intermediate')
allocated_employees=pd.DataFrame(allocated_employees)
print( allocated_employees)
# Out:
#    Employee_id                     Name
# 0      Emp_187           Heinrik Hubber
# 1      Emp_245              Amory Terry
# 2       Emp_57          Issi Chamberlen
# 3      Emp_378            Joyann Eastby
# 4      Emp_293           Ryley Knowlden
# 5      Emp_169             Don Breckell
# 6      Emp_205          Trista Reicharz
# 7      Emp_100       Burch Smallthwaite
# 8      Emp_168         Eduard Schoffler
# 9       Emp_47  Christophorus Lodovichi
# 10     Emp_472          Steward McBoyle
# 11     Emp_193          Hayyim Norcliff
# 12     Emp_257            Norry Dannohl
# 13     Emp_121              Remy Scrane
# 14     Emp_301        Kermie O'Hoolahan
# 15      Emp_66              Zane Stoner
# 16     Emp_233           Glen Haddeston
# 17     Emp_457           Leena McFadyen
# 18     Emp_231           Justis Loosely

# %%
skills = [
    "Python", "JavaScript", "HTML", "CSS", "React", "Angular", "Vue.js", "Node.js", "Django", "Flask",
    "Java", "Kotlin", "Swift", "Objective-C", "C#", ".NET", "PHP", "Ruby", "SQL", "NoSQL",
    "MongoDB", "MySQL", "PostgreSQL", "Git", "Docker", "Kubernetes", "AWS", "Azure", "Google Cloud Platform",
    "RESTful API", "GraphQL", "CI/CD", "Agile Methodologies", "Scrum", "Test-Driven Development",
    "Behavior-Driven Development", "DevOps", "Continuous Integration", "Continuous Deployment", "Microservices",
    "Containerization", "Machine Learning", "Artificial Intelligence", "Data Science", "Data Analysis",
    "Data Visualization", "Statistical Analysis", "Cybersecurity", "Network Security", "Penetration Testing",
    "Cryptography", "Information Security", "UI/UX Design", "Wireframing", "Prototyping", "User Research",
    "Interaction Design", "Responsive Design", "Accessibility", "Product Management", "Agile Product Management",
    "Requirements Analysis", "User Stories", "Business Analysis", "Technical Writing", "Documentation",
    "Support", "Troubleshooting", "Problem Solving", "Communication", "Collaboration", "Leadership"
]

# %%
df=pd.DataFrame(merged_data)    
from collections import Counter

def recommend_training(employee_id):
    # Fetch employee data based on employee_id
    employee_data = df[df['Empid'] == employee_id]
    
    # Extract employee's skills and certificate status
    skills = [skill.strip().lower() for sublist in employee_data['skill_name'].str.split(',') for skill in sublist]
    certificate_status = [status.strip().lower() for sublist in employee_data['certificate_status'].str.split(',') for status in sublist]

    # Find skills without certificates or with rejected certificates
    missing_skills = [skill for skill, status in zip(skills, certificate_status) if status != 'approved']
    
    # If there are missing skills or rejected certificates, recommend one of those skills
    if missing_skills:
        return missing_skills[0]
    
    # Extract the most popular skill from project tech_stack
    tech_stack_skills = [skill.strip().lower() for sublist in df['tech_stack'].str.split(',') for skill in sublist]
    popular_skill = Counter(tech_stack_skills).most_common(1)[0][0]
    
    # Return the most popular skill if there are no missing skills or rejected certificates
    return popular_skill

# Example usage
employee_id = 'Emp_11'  # Replace with desired employee ID
recommended_skill = recommend_training(employee_id)
print("Recommended training skill for employee", employee_id, ":", recommended_skill)
# Out:
# Recommended training skill for employee Emp_11 : java

# %%
data=pd.DataFrame(merged_data.head(100))
data
# Out:
#       Empid             Name  \
# 0   Emp_180   Cassy Berkeley
# 1    Emp_71      Isa Munkley
# 2   Emp_302  Olivero Cuttler
# 3   Emp_207  Rodolphe McNern
# 4   Emp_329       Lem Sobtka
# ..      ...              ...
# 95  Emp_245      Amory Terry
# 96  Emp_203  Meara Hillhouse
# 97  Emp_497    Aeriel D'Oyly
# 98  Emp_481  Leanna Gallahar
# 99   Emp_10   Quintana Coger
#
#                                      certificate_name  \
# 0   Requirements Analysis,MongoDB,Technical Writin...
# 1                     CSS,Problem Solving,Vue.js,.NET
# 2   Wireframing,Network Security,Problem Solving,A...
# 3                 Network Security,MongoDB,NoSQL,Ruby
# 4              HTML,JavaScript,Containerization,Azure
# ..                                                ...
# 95  RESTful API,User Stories,MongoDB,Business Anal...
# 96  MySQL,Google Cloud Platform,Problem Solving,Mo...
# 97       Continuous Deployment,React,User Stories,SQL
# 98             Requirements Analysis,.NET,Swift,Flask
# 99  Swift,MySQL,Penetration Testing,Technical Writing
#
#                      certificate_status  \
# 0   Approved,Approved,Approved,Approved
# 1   Approved,Approved,Approved,Approved
# 2   Approved,Approved,Approved,Approved
# 3   Approved,Approved,Approved,Approved
# 4   Approved,Approved,Approved,Approved
# ..                                  ...
# 95  Approved,Approved,Approved,Approved
# 96  Approved,Approved,Approved,Approved
# 97  Approved,Approved,Approved,Approved
# 98  Approved,Approved,Approved,Approved
# 99  Rejected,Rejected,Rejected,Rejected
#
#                                            skill_name  \
# 0   Troubleshooting,MongoDB,Technical Writing,Requ...
# 1                     CSS,Problem Solving,Vue.js,.NET
# 2   Problem Solving,Wireframing,Network Security,A...
# 3                 Ruby,Network Security,NoSQL,MongoDB
# 4              Containerization,JavaScript,HTML,Azure
# ..                                                ...
# 95  RESTful API,User Stories,Business Analysis,Mon...
# 96  MySQL,Problem Solving,MongoDB,Google Cloud Pla...
# 97       User Stories,React,Continuous Deployment,SQL
# 98             .NET,Flask,Swift,Requirements Analysis
# 99  Swift,Technical Writing,MySQL,Penetration Testing
#
#                                 skill_proficiency  \
# 0              Expert,Advance,Intermidiate,Expert
# 1             Advance,Expert,Advance,Intermidiate
# 2                  Expert,Beginner,Expert,Advance
# 3         Expert,Expert,Intermidiate,Intermidiate
# 4   Intermidiate,Intermidiate,Expert,Intermidiate
# ..                                            ...
# 95          Intermidiate,Beginner,Beginner,Expert
# 96    Intermidiate,Intermidiate,Beginner,Beginner
# 97           Advance,Advance,Advance,Intermidiate
# 98              Beginner,Beginner,Beginner,Expert
# 99     Beginner,Intermidiate,Intermidiate,Advance
#
#                                          project_type  \
# 0   Inventory Management System,Budget Planner,Inv...
# 1   Sales Forecasting Software,Event Management So...
# 2   Web Application,Customer Service Software,Docu...
# 3   Educational Software,Event Management Software...
# 4   Asset Management System,Social Networking Plat...
# ..                                                ...
# 95  Content Management System,E-commerce Platform,...
# 96  Retail Management System,Warehouse Management ...
# 97  Help Desk Software,Email Client,Retail Managem...
# 98  Virtual Assistant,Budget Planner,Backup Soluti...
# 99  Project Management Software,Email Client,Data ...
#
#                                            tech_stack
# 0   Google Cloud Platform,NoSQL,AWS,User Research,...
# 1   Continuous Integration,Technical Writing,Vue.j...
# 2   HTML,React,Vue.js,Wireframing,Penetration Test...
# 3   Ruby,HTML,Vue.js,JavaScript,GraphQL,Flask,CI/C...
# 4   Kotlin,Java,AWS,Data Visualization,Communicati...
# ..                                                ...
# 95  Troubleshooting,Collaboration,GraphQL,CI/CD,Te...
# 96  UI/UX Design,Docker,Accessibility,Behavior-Dri...
# 97  Flask,Vue.js,Requirements Analysis,Continuous ...
# 98  PostgreSQL,GraphQL,Continuous Deployment,Netwo...
# 99  Statistical Analysis,Kubernetes,Django,Flask,C...
#
# [100 rows x 8 columns]

# %%
#!pip install nltk
#merged_data.to_csv('Main_data.csv')
ground_truth=pd.read_csv('Project.testdata.csv')

# %%
import pickle

# %% [markdown]
# # Testing

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem import PorterStemmer
import numpy as np
import pandas as pd


df = pd.DataFrame(merged_data)

# Apply stemming to the combined text of certificate_name, skill_name, and tech_stack
def stem_text(text):
    stemmer = PorterStemmer()
    stemmed_words = [stemmer.stem(word.lower()) for word in text.split(',')]
    return ' '.join(stemmed_words)

df['combined_text'] = df['certificate_name'] + ',' + df['skill_name'] + ',' + df['tech_stack']+','+df['skill_proficiency']+','+df['certificate_status']
df['stemmed_text'] = df['combined_text'].apply(stem_text)

# Define required tech stack and proficiency
required_tech_stack = ["JavaScript,Technical Writing","NoSql"]
required_proficiency = ["Expert", "Advance"]

# Convert requirements to lowercase
required_tech_stack = [stack.lower() for stack in required_tech_stack]
required_proficiency = [proficiency.lower() for proficiency in required_proficiency]
required_status = "approved" 

required_tech_stack=', '.join(required_tech_stack)
proficiency_string = ', '.join(required_proficiency)
# Create feature vector for required tech stack
combined_requirement= required_tech_stack+','+proficiency_string+','+required_status

required_tech_stack_vector = stem_text(combined_requirement)

# Create feature vectors
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['stemmed_text'])

# Calculate cosine similarity with the required tech stack vector
similarities = cosine_similarity(X, vectorizer.transform([required_tech_stack_vector]))

# Add similarity scores to DataFrame
df['similarity_score'] = similarities.flatten()

# Sort employees based on similarity score and select top 10
top_10_employees = df.nlargest(10, 'similarity_score')

# Assuming you have a ground truth dataset with labels indicating whether each employee is suitable for the project or not

ground_truth_df = pd.DataFrame(ground_truth)
merged_df = pd.merge(top_10_employees, ground_truth_df, on=['Empid'], how='left')

# Create 'Suitable_for_project' column and set it to 1 for rows where 'Empid' is present in the ground truth dataset
merged_df['Suitable_for_project'] = merged_df['Empid'].isin(ground_truth_df['Empid']).astype(int)

total_samples = len(merged_df)
correct_predictions = merged_df[merged_df['Suitable_for_project'] == 1]
accuracy = len(correct_predictions==1) / total_samples

# Calculate precision
true_positives = len(correct_predictions)
false_positives = total_samples - true_positives
precision = true_positives / (true_positives + false_positives)

print("Top 10 Employee Recommendations for the Project:")
print(top_10_employees[['Empid', 'Name', 'similarity_score']])
print("\nAccuracy:", accuracy)
print("Precision:", precision)
# Out:
# Top 10 Employee Recommendations for the Project:
#        Empid              Name  similarity_score
# 307  Emp_342  Brandice Iorizzo          0.659186
# 233  Emp_169      Don Breckell          0.480747
# 42   Emp_448    Alaric Kendred          0.479026
# 401  Emp_161    Jemmie Ducarel          0.475870
# 416  Emp_478     Buddie Gergus          0.465695
# 0    Emp_180    Cassy Berkeley          0.463976
# 335  Emp_473    Katharyn Elloy          0.463599
# 389  Emp_417      Tobe Buckbee          0.463250
# 101   Emp_78   Nobie Quidenham          0.457146
# 119  Emp_464   Dacie Pettigree          0.449541
#
# Accuracy: 0.7272727272727273
# Precision: 0.7272727272727273

# %%
correct_predictions
# Out:
#       Empid              Name  \
# 0   Emp_342  Brandice Iorizzo
# 1   Emp_342  Brandice Iorizzo
# 3   Emp_448    Alaric Kendred
# 5   Emp_478     Buddie Gergus
# 6   Emp_180    Cassy Berkeley
# 7   Emp_473    Katharyn Elloy
# 8   Emp_417      Tobe Buckbee
# 10  Emp_464   Dacie Pettigree
#
#                                      certificate_name  \
# 0   C#,Technical Writing,JavaScript,Google Cloud P...
# 1   C#,Technical Writing,JavaScript,Google Cloud P...
# 3              Ruby,Technical Writing,Kubernetes,.NET
# 5   Technical Writing,Prototyping,Documentation,De...
# 6   Requirements Analysis,MongoDB,Technical Writin...
# 7   Data Analysis,Java,Technical Writing,User Stories
# 8         Technical Writing,Scrum,User Research,NoSQL
# 10           Technical Writing,HTML,Kubernetes,Kotlin
#
#                      certificate_status  \
# 0   Approved,Approved,Approved,Approved
# 1   Approved,Approved,Approved,Approved
# 3   Approved,Approved,Approved,Approved
# 5   Approved,Approved,Approved,Approved
# 6   Approved,Approved,Approved,Approved
# 7   Approved,Approved,Approved,Approved
# 8   Approved,Approved,Approved,Approved
# 10  Approved,Approved,Approved,Approved
#
#                                            skill_name  \
# 0   Google Cloud Platform,C#,JavaScript,Technical ...
# 1   Google Cloud Platform,C#,JavaScript,Technical ...
# 3              Kubernetes,Ruby,.NET,Technical Writing
# 5   Technical Writing,DevOps,Documentation,Prototy...
# 6   Troubleshooting,MongoDB,Technical Writing,Requ...
# 7   Technical Writing,Java,User Stories,Data Analysis
# 8         User Research,NoSQL,Technical Writing,Scrum
# 10           Kubernetes,Technical Writing,HTML,Kotlin
#
#                                   skill_proficiency  \
# 0                    Expert,Beginner,Advance,Expert
# 1                    Expert,Beginner,Advance,Expert
# 3                  Advance,Advance,Beginner,Advance
# 5   Intermidiate,Intermidiate,Intermidiate,Beginner
# 6                Expert,Advance,Intermidiate,Expert
# 7               Intermidiate,Advance,Advance,Expert
# 8                  Advance,Beginner,Advance,Advance
# 10                   Expert,Advance,Advance,Advance
#
#                                          project_type  \
# 0   Social Networking Platform,Survey Software,Acc...
# 1   Social Networking Platform,Survey Software,Acc...
# 3   Payment Gateway,Customer Service Software,Paym...
# 5   Help Desk Software,Document Management System,...
# 6   Inventory Management System,Budget Planner,Inv...
# 7   Data Analyzer,Ticketing System,Web Application...
# 8   Customer Relationship Management,Dashboard Cre...
# 10  Customer Relationship Management,Retail Manage...
#
#                                            tech_stack  \
# 0   User Research,Technical Writing,Behavior-Drive...
# 1   User Research,Technical Writing,Behavior-Drive...
# 3   PHP,Communication,JavaScript,Java,Prototyping,...
# 5   CI/CD,Data Analysis,CSS,Collaboration,Java,Pro...
# 6   Google Cloud Platform,NoSQL,AWS,User Research,...
# 7   Test-Driven Development,Business Analysis,Azur...
# 8   Documentation,Leadership,Problem Solving,Machi...
# 10  Objective-C,Behavior-Driven Development,Intera...
#
#                                         combined_text  \
# 0   C#,Technical Writing,JavaScript,Google Cloud P...
# 1   C#,Technical Writing,JavaScript,Google Cloud P...
# 3   Ruby,Technical Writing,Kubernetes,.NET,Kuberne...
# 5   Technical Writing,Prototyping,Documentation,De...
# 6   Requirements Analysis,MongoDB,Technical Writin...
# 7   Data Analysis,Java,Technical Writing,User Stor...
# 8   Technical Writing,Scrum,User Research,NoSQL,Us...
# 10  Technical Writing,HTML,Kubernetes,Kotlin,Kuber...
#
#                                          stemmed_text  similarity_score  \
# 0   c# technical writ javascript google cloud plat...          0.659186
# 1   c# technical writ javascript google cloud plat...          0.659186
# 3   rubi technical writ kubernet .net kubernet rub...          0.479026
# 5   technical writ prototyp document devop technic...          0.465695
# 6   requirements analysi mongodb technical writ tr...          0.463976
# 7   data analysi java technical writ user stori te...          0.463599
# 8   technical writ scrum user research nosql user ...          0.463250
# 10  technical writ html kubernet kotlin kubernet t...          0.449541
#
#             skillName   Proficiency  Suitable_for_project
# 0          JavaScript       Advance                     1
# 1   Technical Writing        Expert                     1
# 3   Technical Writing       Advance                     1
# 5   Technical Writing  Intermidiate                     1
# 6   Technical Writing  Intermidiate                     1
# 7   Technical Writing  Intermidiate                     1
# 8   Technical Writing       Advance                     1
# 10  Technical Writing       Advance                     1

# %% [markdown]
# # Final model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem import PorterStemmer
import numpy as np
import pandas as pd

# Convert dictionary to DataFrame
df = pd.DataFrame(merged_data)

# Apply stemming to the combined text of certificate_name, skill_name, and tech_stack
def stem_text(text):
    stemmer = PorterStemmer()
    # Convert text to lowercase and then apply stemming
    stemmed_words = [stemmer.stem(word.lower()) for word in text.split(',')]
    return ' '.join(stemmed_words)

df['combined_text'] = df['certificate_name'] + ',' + df['skill_name'] + ',' + df['tech_stack']+','+df['skill_proficiency']+','+df['certificate_status']
df['stemmed_text'] = df['combined_text'].apply(stem_text)

# Define required tech stack and proficiency
required_tech_stack = ["JavaScript,Technical Writing","NoSql"]
required_proficiency = ["Expert", "Advance"]

# Convert requirements to lowercase
required_tech_stack = [stack.lower() for stack in required_tech_stack]
required_proficiency = [proficiency.lower() for proficiency in required_proficiency]
required_status = "approved" 

required_tech_stack=', '.join(required_tech_stack)
proficiency_string = ', '.join(required_proficiency)
# Create feature vector for required tech stack
combined_requirement= required_tech_stack+','+proficiency_string+','+required_status

required_tech_stack_vector = stem_text(combined_requirement)

# Create feature vectors
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['stemmed_text'])

# Calculate cosine similarity with the required tech stack vector
similarities = cosine_similarity(X, vectorizer.transform([required_tech_stack_vector]))

# Add similarity scores to DataFrame
df['similarity_score'] = similarities.flatten()

# Sort employees based on similarity score and select top 10
top_10_employees = df.nlargest(10, 'similarity_score')

# Print top 10 employee recommendations
print("Top 10 Employee Recommendations for the Project:")
print(top_10_employees[['Empid', 'Name', 'similarity_score']])
# Out:
# Top 10 Employee Recommendations for the Project:
#        Empid              Name  similarity_score
# 307  Emp_342  Brandice Iorizzo          0.659186
# 233  Emp_169      Don Breckell          0.480747
# 42   Emp_448    Alaric Kendred          0.479026
# 401  Emp_161    Jemmie Ducarel          0.475870
# 416  Emp_478     Buddie Gergus          0.465695
# 0    Emp_180    Cassy Berkeley          0.463976
# 335  Emp_473    Katharyn Elloy          0.463599
# 389  Emp_417      Tobe Buckbee          0.463250
# 101   Emp_78   Nobie Quidenham          0.457146
# 119  Emp_464   Dacie Pettigree          0.449541
